# %%
# TASK 7
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Shahscriptscode/Capstone-Project/main/part1/orders_export.csv')
print("Data loaded automatically from GitHub")
print(df.head())
# Out:
# Data loaded automatically from GitHub
#    id     company  order_id           order_date  shipping_fee
# 0   1   Company A        44  2006-03-24 00:00:00           0.0
# 1   1   Company A        71  2006-05-24 00:00:00           0.0
# 2  27  Company AA        30  2006-01-15 00:00:00         200.0
# 3  27  Company AA        57  2006-04-22 00:00:00         200.0
# 4  28  Company BB        38  2006-03-10 00:00:00          10.0

# %%
# a.
print("Missing counts:\n", df.isnull().sum())
print("\nMissing %:\n", (df.isnull().sum()/len(df))*100)

# b.
df['shipping_fee'] = df['shipping_fee'].fillna(df['shipping_fee'].median())
df['company'] = df['company'].fillna(df['company'].mode()[0])
print("\nAfter imputation:\n", df.isnull().sum())

# c.
before = len(df)
df = df.drop_duplicates()
after = len(df)
print(f"\nRows before: {before}, after: {after}")
# Out:
# Missing counts:
#  id              0
# company         0
# order_id        0
# order_date      0
# shipping_fee    0
# zscore          0
# dtype: int64
#
# Missing %:
#  id              0.0
# company         0.0
# order_id        0.0
# order_date      0.0
# shipping_fee    0.0
# zscore          0.0
# dtype: float64
#
# After imputation:
#  id              0
# company         0
# order_id        0
# order_date      0
# shipping_fee    0
# zscore          0
# dtype: int64
#
# Rows before: 48, after: 48

# %%
# TASK 8
Q1 = df['shipping_fee'].quantile(0.25)
Q3 = df['shipping_fee'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR
outliers_iqr = df[(df['shipping_fee'] < lower) | (df['shipping_fee'] > upper)]
print("IQR outliers:", len(outliers_iqr))

mean = df['shipping_fee'].mean()
std = df['shipping_fee'].std()
df['zscore'] = (df['shipping_fee'] - mean) / std
outliers_z = df[df['zscore'].abs() > 3]
print("Z-score outliers:", len(outliers_z))
# Out:
# IQR outliers: 6
# Z-score outliers: 2
